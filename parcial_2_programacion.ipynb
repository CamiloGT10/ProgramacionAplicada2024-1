# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloGT10/ProgramacionAplicada2024-1/blob/main/parcial_2_programacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive #punto 1
import pandas as pd
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/ABC - Sales.tex'
ventas = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
ventas.head(12) #punto 2
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 0       101       30        5      Heater    2      Fairview Mall
# 1       102       20       14       Piano    2            Rotunda
# 2       103       20       17   Microwave    1  Kessington Market
# 3       104        5        3     Speaker    3      Fairview Mall
# 4       105       10        4  Humidifier    1           Shoppers
# 5       106       14        4  Humidifier    1           Shoppers
# 6       107       28        2     Printer    3  Kessington Market
# 7       108       27       14       Piano    2        Brisby Mall
# 8       109        4        5      Heater    2        Brisby Mall
# 9       110        8        3     Speaker    3           Shoppers
# 10      111       30        4  Humidifier    2           Shoppers
# 11      112        8       13  Microphone    2  Kessington Market

# %%
ventas.tail(15) #punto 3
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 15      116        2        3     Speaker    2        Brisby Mall
# 16      117       10        3     Speaker    3  Kessington Market
# 17      118        8       17   Microwave    3           Shoppers
# 18      119        5        5      Heater    2            Rotunda
# 19      120       28        1   Headphone    1        Brisby Mall
# 20      121        4        5      Heater    3           Shoppers
# 21      122       24       16       Mixer    2        Brisby Mall
# 22      123       10        1   Headphone    2  Kessington Market
# 23      124       13       15      Tripod    1        Brisby Mall
# 24      125       27       17   Microwave    3           Shoppers
# 25      126        7        2     Printer    2  Kessington Market
# 26      127       24       14       Piano    1  Kessington Market
# 27      128       15       13  Microphone    1            Rotunda
# ...

# %%
StoreLoc = ventas['store_location'] #punto 4
print(StoreLoc)
# Out:
# 0         Fairview Mall
# 1               Rotunda
# 2     Kessington Market
# 3         Fairview Mall
# 4              Shoppers
# 5              Shoppers
# 6     Kessington Market
# 7           Brisby Mall
# 8           Brisby Mall
# 9              Shoppers
# 10             Shoppers
# 11    Kessington Market
# 12             Shoppers
# 13              Rotunda
# 14    Kessington Market
# 15          Brisby Mall
# 16    Kessington Market
# 17             Shoppers
# 18              Rotunda
# 19          Brisby Mall
# 20             Shoppers
# 21          Brisby Mall
# 22    Kessington Market
# 23          Brisby Mall
# 24             Shoppers
# 25    Kessington Market
# 26    Kessington Market
# 27              Rotunda
# 28          Brisby Mall
# 29             Shoppers
# Name: store_location, dtype: object

# %%
IdComprador = ventas['cust_id'] #punto 5
print(IdComprador)
# Out:
# 0     30
# 1     20
# 2     20
# 3      5
# 4     10
# 5     14
# 6     28
# 7     27
# 8      4
# 9      8
# 10    30
# 11     8
# 12    13
# 13    30
# 14    20
# 15     2
# 16    10
# 17     8
# 18     5
# 19    28
# 20     4
# 21    24
# 22    10
# 23    13
# 24    27
# 25     7
# 26    24
# 27    15
# 28    14
# 29    13
# Name: cust_id, dtype: int64

# %%
IdVenta = ventas['sale_id'] #punto 6
print(IdVenta)
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120
# 20    121
# 21    122
# 22    123
# 23    124
# 24    125
# 25    126
# 26    127
# 27    128
# 28    129
# 29    130
# Name: sale_id, dtype: int64

# %%
StoreLoc.sort_values(ascending=False) #punto 7
# Out:
# 29             Shoppers
# 9              Shoppers
# 24             Shoppers
# 17             Shoppers
# 12             Shoppers
# 10             Shoppers
# 5              Shoppers
# 4              Shoppers
# 20             Shoppers
# 13              Rotunda
# 1               Rotunda
# 27              Rotunda
# 18              Rotunda
# 6     Kessington Market
# 26    Kessington Market
# 25    Kessington Market
# 22    Kessington Market
# 11    Kessington Market
# 14    Kessington Market
# 16    Kessington Market
# 2     Kessington Market
# 0         Fairview Mall
# 3         Fairview Mall
# 21          Brisby Mall
# 23          Brisby Mall
# 19          Brisby Mall
# 8           Brisby Mall
# 7           Brisby Mall
# 28          Brisby Mall
# 15          Brisby Mall
# Name: store_location, dtype: object

# %%
IdComprador.sort_values(ascending=False) #punto 8
# Out:
# 0     30
# 10    30
# 13    30
# 19    28
# 6     28
# 7     27
# 24    27
# 26    24
# 21    24
# 2     20
# 14    20
# 1     20
# 27    15
# 28    14
# 5     14
# 23    13
# 29    13
# 12    13
# 16    10
# 22    10
# 4     10
# 17     8
# 11     8
# 9      8
# 25     7
# 18     5
# 3      5
# 20     4
# 8      4
# 15     2
# Name: cust_id, dtype: int64

# %%
IdVenta.sort_values(ascending=False) #punto 9
# Out:
# 29    130
# 28    129
# 27    128
# 26    127
# 25    126
# 24    125
# 23    124
# 22    123
# 21    122
# 20    121
# 19    120
# 18    119
# 17    118
# 16    117
# 15    116
# 14    115
# 13    114
# 12    113
# 11    112
# 10    111
# 9     110
# 8     109
# 7     108
# 6     107
# 5     106
# 4     105
# 3     104
# 2     103
# 1     102
# 0     101
# Name: sale_id, dtype: int64

# %%
nombres_columnas = ['product', 'qty', 'store_location'] #punto 10
columnas = ventas[nombres_columnas]

print(columnas)
# Out:
#        product  qty     store_location
# 0       Heater    2      Fairview Mall
# 1        Piano    2            Rotunda
# 2    Microwave    1  Kessington Market
# 3      Speaker    3      Fairview Mall
# 4   Humidifier    1           Shoppers
# 5   Humidifier    1           Shoppers
# 6      Printer    3  Kessington Market
# 7        Piano    2        Brisby Mall
# 8       Heater    2        Brisby Mall
# 9      Speaker    3           Shoppers
# 10  Humidifier    2           Shoppers
# 11  Microphone    2  Kessington Market
# 12      Heater    2           Shoppers
# 13      Tripod    2            Rotunda
# 14  Microphone    2  Kessington Market
# 15     Speaker    2        Brisby Mall
# 16     Speaker    3  Kessington Market
# 17   Microwave    3           Shoppers
# 18      Heater    2            Rotunda
# 19   Headphone    1        Brisby Mall
# 20      Heater    3           Shoppers
# 21       Mixer    2        Brisby Mall
# 22   Headphone    2  Kessington Market
# ...

# %%
ventas.isnull().sum() #punto 11
# Out:
# sale_id           0
# cust_id           0
# prod_id           0
# product           0
# qty               0
# store_location    0
# dtype: int64

# %%
productos_vendidos = ventas.groupby('product')['qty'].sum() #punto 12

print(productos_vendidos)
# Out:
# product
# Dryer          1
# Headphone      3
# Heater        11
# Humidifier     4
# Microphone     5
# Microwave      7
# Mixer          2
# Piano          5
# Printer        5
# Speaker       11
# Tripod         3
# Washer         2
# Name: qty, dtype: int64

# %%
ventas.groupby('prod_id')['qty'].sum() #punto 13
# Out:
# prod_id
# 1      3
# 2      5
# 3     11
# 4      4
# 5     11
# 13     5
# 14     5
# 15     3
# 16     2
# 17     7
# 18     2
# 19     1
# Name: qty, dtype: int64

# %%
ventas.sort_values(by='prod_id') #punto 14
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 22      123       10        1   Headphone    2  Kessington Market
# 19      120       28        1   Headphone    1        Brisby Mall
# 25      126        7        2     Printer    2  Kessington Market
# 6       107       28        2     Printer    3  Kessington Market
# 16      117       10        3     Speaker    3  Kessington Market
# 3       104        5        3     Speaker    3      Fairview Mall
# 15      116        2        3     Speaker    2        Brisby Mall
# 9       110        8        3     Speaker    3           Shoppers
# 4       105       10        4  Humidifier    1           Shoppers
# 5       106       14        4  Humidifier    1           Shoppers
# 10      111       30        4  Humidifier    2           Shoppers
# 18      119        5        5      Heater    2            Rotunda
# 0       101       30        5      Heater    2      Fairview Mall
# ...

# %%
ventas.sort_values(by='cust_id') #punto 15
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 15      116        2        3     Speaker    2        Brisby Mall
# 8       109        4        5      Heater    2        Brisby Mall
# 20      121        4        5      Heater    3           Shoppers
# 3       104        5        3     Speaker    3      Fairview Mall
# 18      119        5        5      Heater    2            Rotunda
# 25      126        7        2     Printer    2  Kessington Market
# 11      112        8       13  Microphone    2  Kessington Market
# 9       110        8        3     Speaker    3           Shoppers
# 17      118        8       17   Microwave    3           Shoppers
# 22      123       10        1   Headphone    2  Kessington Market
# 4       105       10        4  Humidifier    1           Shoppers
# 16      117       10        3     Speaker    3  Kessington Market
# 23      124       13       15      Tripod    1        Brisby Mall
# ...

# %%
ventas.sort_values(by=['cust_id', 'prod_id']) #punto 16
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 15      116        2        3     Speaker    2        Brisby Mall
# 8       109        4        5      Heater    2        Brisby Mall
# 20      121        4        5      Heater    3           Shoppers
# 3       104        5        3     Speaker    3      Fairview Mall
# 18      119        5        5      Heater    2            Rotunda
# 25      126        7        2     Printer    2  Kessington Market
# 9       110        8        3     Speaker    3           Shoppers
# 11      112        8       13  Microphone    2  Kessington Market
# 17      118        8       17   Microwave    3           Shoppers
# 22      123       10        1   Headphone    2  Kessington Market
# 16      117       10        3     Speaker    3  Kessington Market
# 4       105       10        4  Humidifier    1           Shoppers
# 12      113       13        5      Heater    2           Shoppers
# ...

# %%
ventas.sort_index(ascending=False) #punto 17
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 29      130       13       18      Washer    2           Shoppers
# 28      129       14       19       Dryer    1        Brisby Mall
# 27      128       15       13  Microphone    1            Rotunda
# 26      127       24       14       Piano    1  Kessington Market
# 25      126        7        2     Printer    2  Kessington Market
# 24      125       27       17   Microwave    3           Shoppers
# 23      124       13       15      Tripod    1        Brisby Mall
# 22      123       10        1   Headphone    2  Kessington Market
# 21      122       24       16       Mixer    2        Brisby Mall
# 20      121        4        5      Heater    3           Shoppers
# 19      120       28        1   Headphone    1        Brisby Mall
# 18      119        5        5      Heater    2            Rotunda
# 17      118        8       17   Microwave    3           Shoppers
# ...

# %%
ventasOptimizado = ventas.drop_duplicates() #punto 18
ventasOptimizado
# Out:
#     sale_id  cust_id  prod_id     product  qty     store_location
# 0       101       30        5      Heater    2      Fairview Mall
# 1       102       20       14       Piano    2            Rotunda
# 2       103       20       17   Microwave    1  Kessington Market
# 3       104        5        3     Speaker    3      Fairview Mall
# 4       105       10        4  Humidifier    1           Shoppers
# 5       106       14        4  Humidifier    1           Shoppers
# 6       107       28        2     Printer    3  Kessington Market
# 7       108       27       14       Piano    2        Brisby Mall
# 8       109        4        5      Heater    2        Brisby Mall
# 9       110        8        3     Speaker    3           Shoppers
# 10      111       30        4  Humidifier    2           Shoppers
# 11      112        8       13  Microphone    2  Kessington Market
# 12      113       13        5      Heater    2           Shoppers
# ...

# %%
mi_lista = [1, 2, 3, 4, 5] #punto 19
mi_serie = pd.Series(mi_lista)
mi_serie
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
mi_diccionario = {'col1': [1, 2, 3], 'col2': [4, 5, 6]} #punto 20
mi_dataframe = pd.DataFrame(mi_diccionario)
mi_dataframe
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6
